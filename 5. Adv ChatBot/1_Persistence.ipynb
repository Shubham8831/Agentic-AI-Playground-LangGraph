# %% [markdown]
# Below are **clean, simple, copy-paste friendly notes** you can directly use in a **Jupyter notebook (Markdown cell)**.
# I’ll explain everything in **plain English**, step-by-step, with examples and **no heavy jargon**.
#
# ---
#
# # 📌 Persistence in LangGraph (Simple Notes)
#
# ## 1️⃣ What is Persistence?
#
# **Persistence** means the ability to **save the state of a workflow** so that it can be:
#
# * Restored later
# * Continued if it stops or fails
# * Reused across multiple runs
#
# ### In simple words:
#
# > Persistence lets LangGraph remember what happened in a workflow, even after it ends or crashes.
#
# ---
#
# ## 2️⃣ Default Behavior (Without Persistence)
#
# By default, LangGraph behaves like this:
#
# * A workflow runs
# * Nodes execute one by one
# * Final output is returned
# * ❌ **All state data is deleted after the workflow ends**
#
# ### Example:
#
# If your workflow state was:
#
# ```python
# {
#   "user_message": "Hi",
#   "intent": "greeting",
#   "reply": "Hello!"
# }
# ```
#
# After execution:
#
# * ❌ This state is **lost**
# * ❌ You cannot resume or inspect past steps
#
# ---
#
# ## 3️⃣ What Changes With Persistence?
#
# When **persistence is enabled**:
#
# * ✅ The **final state is saved**
# * ✅ All **intermediate states are saved**
# * ✅ Any value that changes during execution is recorded
#
# ### Example:
#
# If your workflow changes state like this:
#
# Step 1:
#
# ```python
# {"user_message": "Hi"}
# ```
#
# Step 2:
#
# ```python
# {"user_message": "Hi", "intent": "greeting"}
# ```
#
# Step 3:
#
# ```python
# {"user_message": "Hi", "intent": "greeting", "reply": "Hello!"}
# ```
#
# ➡️ **All 3 states are stored**, not just the final one.
#
# ---
#
# ## 4️⃣ Fault Tolerance (Very Important)
#
# ### What is Fault Tolerance?
#
# **Fault tolerance** means:
#
# > If something fails, the system does not lose progress.
#
# In LangGraph:
#
# * If a **node crashes or errors**
# * The **last saved state** is still available
# * The workflow can **restart from where it failed**
#
# ### Example:
#
# Workflow:
#
# ```
# Node A → Node B → Node C → Node D
# ```
#
# If **Node C fails**:
#
# * Node A & B states are already saved
# * You don’t need to rerun everything
# * Execution can resume from **Node C**
#
# ➡️ This makes workflows **safe and reliable**
#
# ---
#
# ## 5️⃣ Why Is Persistence Useful?
#
# ### Main Applications
#
# #### 🤖 Chatbots
#
# * Remember past conversation
# * Resume chats after refresh
# * Maintain context across messages
#
# #### 🔁 Long Workflows
#
# * Resume long-running tasks
# * Avoid recomputation
#
# #### 🧠 AI Agents
#
# * Track reasoning steps
# * Recover from partial failures
#
# ---
#
# ## 6️⃣ How LangGraph Implements Persistence
#
# LangGraph uses something called **Checkpoints**.
#
# ---
#
# # 📌 Checkpoints in LangGraph
#
# ## 7️⃣ What is a Checkpoint?
#
# A **checkpoint** is a **saved snapshot of the workflow state** at a specific time.
#
# Think of it like:
#
# > Pressing “Save Game” while playing a game 🎮
#
# ---
#
# ## 8️⃣ Where Are Checkpoints Created?
#
# Checkpoints are created at:
#
# * Start of the workflow
# * After each major execution step
# * At the end of the workflow
#
# These saved states are stored in a **database or storage layer**.
#
# ---
#
# ## 9️⃣ Supersteps (Key Concept)
#
# ### What is a Superstep?
#
# A **superstep** is:
#
# > One full round of node execution in the graph
#
# LangGraph treats:
#
# * **Each superstep as a checkpoint**
#
# ### Simple explanation:
#
# * Nodes execute
# * State updates
# * ✅ State is saved as a checkpoint
#
# ---
#
# ## 🔁 Flow Example (With Checkpoints)
#
# ```
# Start
#   ↓   (Checkpoint 1)
# Node A
#   ↓   (Checkpoint 2)
# Node B
#   ↓   (Checkpoint 3)
# Node C
#   ↓   (Checkpoint 4)
# End
# ```
#
# At **each step**, the state is saved.
#
# ---
#
# ## 10️⃣ What Exactly Is Saved?
#
# Each checkpoint stores:
#
# * Full workflow state
# * Updated values only (efficient storage)
# * Metadata like timestamps and thread ID
#
# ---
#
# # 📌 Threads in Persistence
#
# ## 11️⃣ What is a Thread?
#
# A **thread** represents:
#
# > One execution instance of a workflow
#
# Every time you run a workflow:
#
# * A **unique thread ID** is generated
#
# ---
#
# ## 12️⃣ Why Thread IDs Matter?
#
# Thread IDs allow you to:
#
# * Retrieve past states
# * Resume a specific workflow run
# * Keep multiple conversations separate
#
# ### Example:
#
# ```text
# Thread ID 1 → User A chatbot conversation
# Thread ID 2 → User B chatbot conversation
# ```
#
# Each thread has:
#
# * Its own checkpoints
# * Its own saved state history
#
# ---
#
# ## 13️⃣ Using Threads Practically
#
# With thread IDs, you can:
#
# * Load previous conversation state
# * Restart workflows mid-way
# * Debug past executions
#
# ➡️ This is **critical for production systems**
#
# ---
#
# # 📌 Summary (Quick Revision)
#
# ## Persistence
#
# * Saves workflow state
# * Prevents data loss
# * Enables recovery and resume
#
# ## Fault Tolerance
#
# * Saves intermediate state
# * Restarts from failure point
#
# ## Checkpoints
#
# * Saved snapshots of state
# * Created at each superstep
#
# ## Supersteps
#
# * One round of node execution
# * Automatically checkpointed
#
# ## Threads
#
# * Unique workflow execution IDs
# * Used to retrieve and resume state

# %% [markdown]
# ```
# START
#   |
#   v
# +-------+
# | NODE1 |  <=== checkpoint
# +-------+
#   |
#   v
# Superstep ①
#   |
#   v
# +-------+          +--------+
# | NODE2 | <------> | NODE1  |
# +-------+          +--------+
#   |                  ^
#   v                  |
# +--------+           |
# | NODE3  |-----------
# +--------+
#   |
#   v
# Superstep ②
#   |
#   v
# +--------+
# | NODE4  | <=== checkpoint
# +--------+
#   |
#   v
# Superstep ③
#   |
#   v
# +--------+
# |  I/O   |
# +--------+ <=== checkpoint
#
# Superstep ④
#
#   ↑
#   |
# +--------+
# | NODE1  |  <=== checkpoint
# +--------+
#
# Superstep ⑤
# ```

# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_groq import ChatGroq
from dotenv import load_dotenv
from langgraph.checkpoint.memory import InMemorySaver # this is kind of checkpointer that helps in implementation on checkpointers, this saves all the states in RAM this is mostly used in demo projects in production we use different checkpointers

# %%
import os
load_dotenv()
key = os.getenv("GROQ_API_KEY")
llm = ChatGroq(model="llama-3.3-70b-versatile", api_key=key)
llm.invoke("hello").content
# Out:
# 'Hello. How can I assist you today?'

# %%
#state

class JokeState(TypedDict):
    topic: str
    joke: str
    explanation : str

# %%
def generate_joke(state: JokeState):
    prompt = f"write an joke on topic - {state['topic']} in 20 words"
    joke = llm.invoke(prompt).content
    return {"joke": joke}

# %%
def generate_explanation(state: JokeState):
    prompt = f"write explanation for the joke - {state['joke']} in 30 words"
    explanation = llm.invoke(prompt).content
    return {"explanation": explanation}

# %%
graph = StateGraph(JokeState)

graph.add_node("generate_joke", generate_joke)
graph.add_node("generate_explanation", generate_explanation)

graph.add_edge(START, "generate_joke")
graph.add_edge("generate_joke", 'generate_explanation')
graph.add_edge('generate_explanation', END)

# IN ORDER TO MAKE SURE OUR WORKFLOW IMPLEMENT IMPLEMENTS PERSISTENT
#WE MAKE A CHECKPOINTER
checkpointer = InMemorySaver()

workflow = graph.compile(checkpointer=checkpointer) # send checkpointer while compiling the graph

# %%
config1 = {"configurable":{'thread_id': "1"}} # while executing persistence we send a thread id and against that thread id all the state will be stored 

workflow.invoke({"topic":"ai"}, config=config1)
# Out:
# {'topic': 'ai',
#  'joke': 'Why did AI go to therapy? It had a little "glitch" in its personality matrix always.',
#  'explanation': 'The joke plays on "glitch" meaning both a technical error and a personality flaw, humorously applying human therapy to AI\'s digital issues.'}

# %%
# THIS WILL GIVE THIS FINAL STATE
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'ai', 'joke': 'Why did AI go to therapy? It had a little "glitch" in its personality matrix always.', 'explanation': 'The joke plays on "glitch" meaning both a technical error and a personality flaw, humorously applying human therapy to AI\'s digital issues.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f12b7-1b7d-61e3-8002-ded27670e9f7'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-01-14T09:28:54.224501+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f12b7-189c-67fe-8001-eea1afa480cb'}}, tasks=(), interrupts=())

# %%
# IF WE HAVE USED THE DATABASE MEMROY SAVER THEN AFTER MANY DAYS IF YOU RE RUN THE ABOVE CODE IT WILL GIVE THE ALLL THE SATE RESULT

# %%
# TO SEE INTERMEDIATE STATE VALUES
list(workflow.get_state_history(config1)) # we see 4 values for all the checkpointer
# Out:
# [StateSnapshot(values={'topic': 'ai', 'joke': 'Why did AI go to therapy? It had a little "glitch" in its personality matrix always.', 'explanation': 'The joke plays on "glitch" meaning both a technical error and a personality flaw, humorously applying human therapy to AI\'s digital issues.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f12b7-1b7d-61e3-8002-ded27670e9f7'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-01-14T09:28:54.224501+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f12b7-189c-67fe-8001-eea1afa480cb'}}, tasks=(), interrupts=()),
# ...

# %%
config2 = {"configurable":{'thread_id': "2"}} 

workflow.invoke({"topic":"ai"}, config=config2)

list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'ai', 'joke': 'Why did AI go to therapy? It had a little "glitch" in its personality matrix always.', 'explanation': 'The joke plays on "glitch" meaning both a technical error and a personality flaw, humorously applying human therapy to AI\'s digital issues.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f12b7-1b7d-61e3-8002-ded27670e9f7'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-01-14T09:28:54.224501+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f12b7-189c-67fe-8001-eea1afa480cb'}}, tasks=(), interrupts=()),
# ...

# %% [markdown]
# ### Benefits of Persistence in AI Systems
#
# - **🔹 1. Short-Term Memory** : Essential for chatbots to maintain conversation context.
#
#
# - **🔹 2. Fault Tolerance** : Allows resuming workflows from the last known state.      Stores intermediate data for recovery.
#
#
# - **🔹 3. Time Travel (Debugging)** : Enables replaying past states.         Helps trace and fix bugs efficiently.
#
#
# - **🔹 4. Human-in-the-Loop** : Maintains continuity during manual interventions.           Supports interactive AI workflows.

# %% [markdown]
# ### 1. Fault Tolerance

# %%
import time
# 1. Define the state
class CrashState(TypedDict):
    input: str
    step1: str 
    step2: str

# %%
# 2. Define steps
def step_1(state: CrashState) -> CrashState:
    print("✅ Step 1 executed")
    return {"step1": "done", "input": state["input"]}

def step_2(state: CrashState) -> CrashState:
    print("⏳ Step 2 hanging... now manually interrupt from the notebook toolbar (STOP button)")
    time.sleep(1000)  # Simulate long-running hang
    return {"step2": "done"}

def step_3(state: CrashState) -> CrashState:
    print("✅ Step 3 executed")
    return {"done": True}

# %%
# 3. Build the graph
builder = StateGraph(CrashState)
builder.add_node("step_1", step_1)
builder.add_node("step_2", step_2)
builder.add_node("step_3", step_3)

builder.set_entry_point("step_1")
builder.add_edge("step_1", "step_2")
builder.add_edge("step_2", "step_3")
builder.add_edge("step_3", END)

checkpointer = InMemorySaver()
graph = builder.compile(checkpointer=checkpointer)

# %%
try:
    print("▶️ Running graph: Please manually interrupt during Step 2...")
    graph.invoke({"input": "start"}, config={"configurable": {"thread_id": 'thread-1'}})
except KeyboardInterrupt:
    print("❌ Kernel manually interrupted (crash simulated).")
# Out:
# ▶️ Running graph: Please manually interrupt during Step 2...
# ✅ Step 1 executed
# ⏳ Step 2 hanging... now manually interrupt from the notebook toolbar (STOP button)

# %%
# 6. Re-run to show fault-tolerant resume
print("\n🔁 Re-running the graph to demonstrate fault tolerance...")
final_state = graph.invoke(None, config={"configurable": {"thread_id": 'thread-1'}}) # we give none to tell we wamt to resume where it previously stopped
print("\n✅ Final State:", final_state)
# Out:
# 🔁 Re-running the graph to demonstrate fault tolerance...
# ---------------------------------------------------------------------------
# EmptyInputError                           Traceback (most recent call last)
# Cell In[22], line 3
#       1 # 6. Re-run to show fault-tolerant resume
#       2 print("\n🔁 Re-running the graph to demonstrate fault tolerance...")
# ----> 3 final_state = graph.invoke(None, config={"configurable": {"thread_id": 'thread-1'}}) # we give none to tell we wamt to resume where it previously stopped
#       4 print("\n✅ Final State:", final_state)
#
# File c:\Users\shubu\Desktop\Agentic AI\my_env\Lib\site-packages\langgraph\pregel\main.py:3019, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, **kwargs)
#    3016 chunks: list[dict[str, Any] | Any] = []
#    3017 interrupts: list[Interrupt] = []
# -> 3019 for chunk in self.stream(
#    3020     input,
#    3021     config,
# ...

# %%
list(graph.get_state_history({"configurable": {"thread_id": 'thread-1'}}))
# Out:
# []

# %% [markdown]
# ### Time Travel

# %%
# we will pass checkpoint id to get intermediate state
workflow.get_state({"configurable": {"thread_id": "1", "checkpoint_id": "1f0f12b7-15ca-6d25-8000-34a0d17d5668"}})
# Out:
# StateSnapshot(values={'topic': 'ai'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_id': '1f0f12b7-15ca-6d25-8000-34a0d17d5668'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-01-14T09:28:53.627178+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f12b7-15c4-6b3a-bfff-4154f3bbac32'}}, tasks=(PregelTask(id='b452f4e7-e452-b04a-6aa9-a4f732f58577', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did AI go to therapy? It had a little "glitch" in its personality matrix always.'}),), interrupts=())

# %%
# and to start execution from the intermediate state and input state is given as none
workflow.invoke({}, {"configurable": {"thread_id": "1", "checkpoint_id": "1f0f12b7-15ca-6d25-8000-34a0d17d5668"}})
# Out:
# {'topic': 'ai',
#  'joke': 'Why did the AI program go to therapy? It had a little "glitch" in its personality always.',
#  'explanation': 'The joke plays on "glitch" meaning both a technical issue and a personality flaw, humorously applying human therapy to an AI program.'}

# %%
# we will see more states as we did time travel
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'ai', 'joke': 'Why did the AI program go to therapy? It had a little "glitch" in its personality always.', 'explanation': 'The joke plays on "glitch" meaning both a technical issue and a personality flaw, humorously applying human therapy to an AI program.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f12c7-e118-66a0-8004-225c16f2274e'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2026-01-14T09:36:24.441777+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f12c7-de77-6cdc-8003-4ec47ac2baad'}}, tasks=(), interrupts=()),
# ...

# %% [markdown]
# ### Updating State

# %%
# WE CAN CHANGE PARTICULATE STATE VALUE AT ANY CHECKPOINT (at last we changed the topic)

workflow.update_state({"configurable": {"thread_id": "1", "checkpoint_id": "1f06cc6e-7232-6cb1-8000-f71609e6cec5", "checkpoint_ns": ""}}, {'topic':'samosa'})
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f0f12c9-0b14-6359-8000-24d35064254d'}}

# %%
# we will get additional state memory

list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'samosa'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f12c9-0b14-6359-8000-24d35064254d'}}, metadata={'source': 'update', 'step': 0, 'parents': {}}, created_at='2026-01-14T09:36:55.687629+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f06cc6e-7232-6cb1-8000-f71609e6cec5'}}, tasks=(PregelTask(id='c095d2e5-6674-f20e-c859-89ef43586686', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result=None),), interrupts=()),
# ...

# %%
# Invoking for samosa
workflow.invoke(None, {"configurable": {"thread_id": "1", "checkpoint_id": "1f0f12c9-0b14-6359-8000-24d35064254d"}})
# Out:
# {'topic': 'samosa',
#  'joke': 'Why was samosa in therapy? It was feeling a little "crunchy" under the pressure always.',
#  'explanation': 'The joke plays on "crunchy" as a samosa\'s texture and emotional state, humorously linking its physical characteristic to feeling overwhelmed under pressure.'}

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'samosa', 'joke': 'Why was samosa in therapy? It was feeling a little "crunchy" under the pressure always.', 'explanation': 'The joke plays on "crunchy" as a samosa\'s texture and emotional state, humorously linking its physical characteristic to feeling overwhelmed under pressure.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f12cd-5d03-6577-8002-29b8079d6575'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-01-14T09:38:51.653227+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f12cd-591e-60db-8001-ae08b00afe01'}}, tasks=(), interrupts=()),
# ...
